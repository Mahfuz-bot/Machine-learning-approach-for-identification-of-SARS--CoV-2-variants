# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Import

# %%
# ! nvidia-smi
# !pip install tensorflow-gpu
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
# import tensorflow_docs as tfdocs
# import tensorflow_docs.modeling
# import tensorflow_docs.plots
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.models import Sequential
from keras.layers.embeddings import Embedding
from tensorflow.keras.layers import Activation, Dense, Flatten,Bidirectional, Conv1D, MaxPooling1D, LSTM, Dropout
from keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.utils import shuffle 
from tensorflow.keras import regularizers
from keras.regularizers import l2,l1
import seaborn as sns
import matplotlib.pyplot as plt 
from tensorflow.keras.metrics import categorical_crossentropy
# from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import itertools
# import re
from  IPython import display
import random
import pathlib
import shutil
import tempfile
from functools import lru_cache
from keras import backend as K
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Data

# %%
train_path = "/content/drive/MyDrive/Thesis/cmpl_data/train.csv"
test_path = "/content/drive/MyDrive/Thesis/cmpl_data/test.csv"
df = pd.read_csv(train_path)
pf = pd.read_csv(test_path)

# %%
# # check the individual character
# def has(matrix):
#     max_value=0
#     for i in range (0,len(matrix)):
#         if (len(matrix[i])>max_value):
#             max_value=len(matrix[i])
#     vectorSize=max_value
#     print('v',vectorSize)
#     count = 0
#     for i in range(len(matrix)):
#         for j in range (0, len(matrix[i])):
#             if (matrix[i][j]=='Z'):
#                 count += 1
#     return count  
# d = df['seq'].values.ravel()
# # p = pf['seq'].values.ravel()
# # v = vf['seq'].values.ravel()
# d = has(d)
# # p = has(p)
# # v = has(v)
# # print('d:',d,'p:',p,'v:',v)
# print('d:',d)

# %%
def seq_conversion(matrix):
    # n = [1,2,3,4] #5
    r = [3,4]
    y = [1,2] #5 
    k = [2,3] #5
    m = [1,4]
    s = [1,3]
    w = [2,4] #5
    b = [1,2,3] #5
    h = [1,2,4]
    d = [2,3,4] #5
    v = [1,3,4]
    
    vectorSize= 29922
    # A:4, G:3, C:1, T:2 U:5
    out_data=[]
    for i in range (len(matrix)):
        sample=np.zeros(vectorSize)
        for j in range (0, len(matrix[i])):
            if(matrix[i][j]=='C'):
              sample[j]=1
            elif(matrix[i][j]=='T'):
              sample[j]=2
            elif(matrix[i][j]=='G'):
              sample[j]=3
            elif(matrix[i][j]=='A'):
              sample[j]=4
            # elif(matrix[i][j]=='U'):
            #   sample[j]=5
            # elif(matrix[i][j]=='N'):
            #   sample[j]=0
            elif(matrix[i][j]=='R'):
              sample[j]=random.choice(r)
            elif(matrix[i][j]=='Y'):
              sample[j]=random.choice(y)
            elif(matrix[i][j]=='K'):
              sample[j]=random.choice(k)
            elif(matrix[i][j]=='M'):
              sample[j]=random.choice(m)
            elif(matrix[i][j]=='S'):
              sample[j]=random.choice(s)
            elif(matrix[i][j]=='W'):
              sample[j]=random.choice(w)
            elif(matrix[i][j]=='B'):
              sample[j]=random.choice(b) 
            elif(matrix[i][j]=='H'):
              sample[j]=random.choice(h) 
            elif(matrix[i][j]=='D'):
              sample[j]=random.choice(d) 
            elif(matrix[i][j]=='V'):
              sample[j]=random.choice(v) 
                
            else:
              sample[j] = 0
        out_data.append(sample)
    return out_data

# %%
train_data,train_label = df['seq'],df['variant_label']
test_data,test_label = pf['seq'],pf['variant_label']
# train_data,test_data,train_label,test_label = train_test_split(data, label, test_size=0.1, random_state=230)
# Train data conversion
train_data  = train_data.values.ravel()
train_data = np.asarray(seq_conversion(train_data), dtype=np.float32)                      
train_label = train_label.to_numpy().astype('int8')
# Test data conversion
test_data  = test_data.values.ravel()
test_data = np.asarray(seq_conversion(test_data), dtype=np.float32)                      
test_label = test_label.to_numpy().astype('int8')

# %%
# Shuffle the train_sample and test_sample
train_data, train_label = shuffle(train_data, train_label)
test_data, test_label = shuffle(test_data, test_label)
# Scaled data
train_data = train_data/4
test_data = test_data/4
# Change the dimension for model purpose
train_data = np.expand_dims(train_data, -1)
test_data = np.expand_dims(test_data, -1)

# %% [markdown]
# ##Model Code

# %%
train_data.shape
# Out:
# (6000, 29922, 1)

# %%
# Save model weight's for each epoch and monitor the val_loss
checkpoint_path = '/content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt'
def get_callbacks():
  return [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=6,restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1),
  ]

# %%
# Build the model

def create_model(): 

    num_classes = 4
    model = Sequential([
    Conv1D(filters=16, kernel_size=6, strides=6,
            input_shape=(train_data.shape[1],train_data.shape[2]),       
    padding="same",activation='relu',kernel_regularizer=regularizers.L2(0.0001)),
    MaxPooling1D(pool_size=6,  strides=6, padding='valid'),
    Conv1D(filters=16, kernel_size=6, strides=6,
            input_shape=(train_data.shape[1],train_data.shape[2]),       
    padding="same",activation='relu',kernel_regularizer=regularizers.L2(0.0001)),
    MaxPooling1D(pool_size=6,  strides=6, padding='valid'),
    Bidirectional(LSTM(units=16,activation='relu',
         kernel_regularizer=regularizers.L2(0.0001),return_sequences=True)),
    # Dropout(rate=0.5),
    Flatten(),
    Dense(num_classes, activation='softmax')
    ])


#   compile the model
    model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate= 0.0001),
                metrics=['accuracy'])
  
  
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_25 (Conv1D)           (None, 4987, 16)          112
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 831, 16)           0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 139, 16)           1552
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 23, 16)            0
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 23, 32)            4224
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 736)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 2948
# =================================================================
# Total params: 8,836
# Trainable params: 8,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
batchSize = 6
epoch = 100
history = model.fit(train_data, train_label,
        validation_split=0.2,
        batch_size=batchSize,
        epochs=epoch,  
        shuffle=True,
        verbose=2,
        callbacks=[get_callbacks()])
# Out:
# Epoch 1/100
# 800/800 - 21s - loss: 1.3906 - accuracy: 0.2567 - val_loss: 1.3878 - val_accuracy: 0.4508
#
# Epoch 00001: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 2/100
# 800/800 - 19s - loss: 1.3846 - accuracy: 0.3338 - val_loss: 1.3781 - val_accuracy: 0.5067
#
# Epoch 00002: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 3/100
# 800/800 - 19s - loss: 1.3589 - accuracy: 0.3871 - val_loss: 1.2983 - val_accuracy: 0.2808
#
# Epoch 00003: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 4/100
# 800/800 - 19s - loss: 1.0811 - accuracy: 0.4958 - val_loss: 1.0028 - val_accuracy: 0.5050
#
# Epoch 00004: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 5/100
# 800/800 - 19s - loss: 1.0154 - accuracy: 0.5325 - val_loss: 0.9821 - val_accuracy: 0.5658
#
# Epoch 00005: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 6/100
# 800/800 - 20s - loss: 0.9938 - accuracy: 0.5404 - val_loss: 0.9438 - val_accuracy: 0.5717
#
# Epoch 00006: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 7/100
# 800/800 - 20s - loss: 0.9609 - accuracy: 0.5592 - val_loss: 0.9814 - val_accuracy: 0.5633
#
# Epoch 00007: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 8/100
# 800/800 - 20s - loss: 0.9326 - accuracy: 0.5779 - val_loss: 0.9170 - val_accuracy: 0.5708
#
# Epoch 00008: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 9/100
# 800/800 - 19s - loss: 0.9117 - accuracy: 0.5900 - val_loss: 0.8967 - val_accuracy: 0.5492
#
# Epoch 00009: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 10/100
# 800/800 - 20s - loss: 0.8960 - accuracy: 0.6025 - val_loss: 0.8590 - val_accuracy: 0.6292
#
# Epoch 00010: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 11/100
# 800/800 - 20s - loss: 0.8798 - accuracy: 0.6133 - val_loss: 1.0575 - val_accuracy: 0.4817
#
# Epoch 00011: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 12/100
# 800/800 - 20s - loss: 0.8723 - accuracy: 0.6187 - val_loss: 0.9903 - val_accuracy: 0.5600
#
# Epoch 00012: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 13/100
# 800/800 - 19s - loss: 0.8513 - accuracy: 0.6385 - val_loss: 0.8302 - val_accuracy: 0.6692
#
# Epoch 00013: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 14/100
# 800/800 - 19s - loss: 0.8317 - accuracy: 0.6550 - val_loss: 0.8325 - val_accuracy: 0.6533
#
# Epoch 00014: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 15/100
# 800/800 - 19s - loss: 0.8206 - accuracy: 0.6625 - val_loss: 0.7965 - val_accuracy: 0.6708
#
# Epoch 00015: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 16/100
# 800/800 - 19s - loss: 0.8148 - accuracy: 0.6637 - val_loss: 0.7933 - val_accuracy: 0.6742
#
# Epoch 00016: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 17/100
# 800/800 - 20s - loss: 0.7893 - accuracy: 0.6790 - val_loss: 0.7777 - val_accuracy: 0.6833
#
# Epoch 00017: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 18/100
# 800/800 - 19s - loss: 0.7774 - accuracy: 0.6919 - val_loss: 0.7485 - val_accuracy: 0.7125
#
# Epoch 00018: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 19/100
# 800/800 - 20s - loss: 0.7562 - accuracy: 0.7050 - val_loss: 0.7483 - val_accuracy: 0.7142
#
# Epoch 00019: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 20/100
# 800/800 - 19s - loss: 0.7449 - accuracy: 0.7077 - val_loss: 0.7641 - val_accuracy: 0.6717
#
# Epoch 00020: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 21/100
# 800/800 - 19s - loss: 0.7324 - accuracy: 0.7144 - val_loss: 0.7397 - val_accuracy: 0.7317
#
# Epoch 00021: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 22/100
# 800/800 - 20s - loss: 0.7144 - accuracy: 0.7240 - val_loss: 0.8194 - val_accuracy: 0.6533
#
# Epoch 00022: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 23/100
# 800/800 - 20s - loss: 0.7147 - accuracy: 0.7256 - val_loss: 0.7215 - val_accuracy: 0.7242
#
# Epoch 00023: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 24/100
# 800/800 - 20s - loss: 0.6887 - accuracy: 0.7344 - val_loss: 0.6822 - val_accuracy: 0.7342
#
# Epoch 00024: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 25/100
# 800/800 - 20s - loss: 0.6839 - accuracy: 0.7377 - val_loss: 0.7666 - val_accuracy: 0.6850
#
# Epoch 00025: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 26/100
# 800/800 - 20s - loss: 0.6740 - accuracy: 0.7392 - val_loss: 0.6774 - val_accuracy: 0.7592
#
# Epoch 00026: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 27/100
# 800/800 - 20s - loss: 0.6762 - accuracy: 0.7390 - val_loss: 0.6696 - val_accuracy: 0.7300
#
# Epoch 00027: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 28/100
# 800/800 - 20s - loss: 0.6470 - accuracy: 0.7558 - val_loss: 0.6600 - val_accuracy: 0.7483
#
# Epoch 00028: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 29/100
# 800/800 - 19s - loss: 0.6479 - accuracy: 0.7554 - val_loss: 0.7116 - val_accuracy: 0.7142
#
# Epoch 00029: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 30/100
# 800/800 - 20s - loss: 0.6417 - accuracy: 0.7494 - val_loss: 0.6827 - val_accuracy: 0.7467
#
# Epoch 00030: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 31/100
# 800/800 - 20s - loss: 0.6348 - accuracy: 0.7571 - val_loss: 0.6701 - val_accuracy: 0.7642
#
# Epoch 00031: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 32/100
# 800/800 - 19s - loss: 0.6392 - accuracy: 0.7619 - val_loss: 0.6284 - val_accuracy: 0.7792
#
# Epoch 00032: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 33/100
# 800/800 - 20s - loss: 0.6200 - accuracy: 0.7700 - val_loss: 0.6684 - val_accuracy: 0.7558
#
# Epoch 00033: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 34/100
# 800/800 - 20s - loss: 0.6157 - accuracy: 0.7746 - val_loss: 0.6355 - val_accuracy: 0.7450
#
# Epoch 00034: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 35/100
# 800/800 - 20s - loss: 0.6083 - accuracy: 0.7750 - val_loss: 0.6645 - val_accuracy: 0.7717
#
# Epoch 00035: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 36/100
# 800/800 - 19s - loss: 0.5988 - accuracy: 0.7792 - val_loss: 0.6216 - val_accuracy: 0.7675
#
# Epoch 00036: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 37/100
# 800/800 - 20s - loss: 0.5939 - accuracy: 0.7760 - val_loss: 0.6550 - val_accuracy: 0.7517
#
# Epoch 00037: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 38/100
# 800/800 - 19s - loss: 0.5919 - accuracy: 0.7815 - val_loss: 0.5995 - val_accuracy: 0.7975
#
# Epoch 00038: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 39/100
# 800/800 - 19s - loss: 0.5740 - accuracy: 0.7877 - val_loss: 0.6071 - val_accuracy: 0.7858
#
# Epoch 00039: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 40/100
# 800/800 - 20s - loss: 0.5724 - accuracy: 0.7923 - val_loss: 0.6340 - val_accuracy: 0.7600
#
# Epoch 00040: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 41/100
# 800/800 - 19s - loss: 0.5635 - accuracy: 0.7940 - val_loss: 0.6471 - val_accuracy: 0.7542
#
# Epoch 00041: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 42/100
# 800/800 - 19s - loss: 0.5567 - accuracy: 0.7969 - val_loss: 0.5824 - val_accuracy: 0.7967
#
# Epoch 00042: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 43/100
# 800/800 - 19s - loss: 0.5539 - accuracy: 0.7958 - val_loss: 0.5978 - val_accuracy: 0.7833
#
# Epoch 00043: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 44/100
# 800/800 - 19s - loss: 0.5342 - accuracy: 0.8058 - val_loss: 0.6337 - val_accuracy: 0.7758
#
# Epoch 00044: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 45/100
# 800/800 - 19s - loss: 0.5308 - accuracy: 0.8035 - val_loss: 0.5394 - val_accuracy: 0.8100
#
# Epoch 00045: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 46/100
# 800/800 - 20s - loss: 0.5240 - accuracy: 0.8081 - val_loss: 0.5530 - val_accuracy: 0.8067
#
# Epoch 00046: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 47/100
# 800/800 - 20s - loss: 0.5228 - accuracy: 0.8108 - val_loss: 0.5876 - val_accuracy: 0.7875
#
# Epoch 00047: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 48/100
# 800/800 - 20s - loss: 0.5223 - accuracy: 0.8129 - val_loss: 0.5948 - val_accuracy: 0.7733
#
# Epoch 00048: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 49/100
# 800/800 - 19s - loss: 0.5094 - accuracy: 0.8158 - val_loss: 0.5157 - val_accuracy: 0.8100
#
# Epoch 00049: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 50/100
# 800/800 - 19s - loss: 0.5008 - accuracy: 0.8188 - val_loss: 0.5229 - val_accuracy: 0.8233
#
# Epoch 00050: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 51/100
# 800/800 - 19s - loss: 0.4964 - accuracy: 0.8225 - val_loss: 0.5491 - val_accuracy: 0.8083
#
# Epoch 00051: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 52/100
# 800/800 - 19s - loss: 0.4969 - accuracy: 0.8196 - val_loss: 0.6158 - val_accuracy: 0.7992
#
# Epoch 00052: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 53/100
# 800/800 - 20s - loss: 0.4782 - accuracy: 0.8206 - val_loss: 0.5493 - val_accuracy: 0.7900
#
# Epoch 00053: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 54/100
# 800/800 - 20s - loss: 0.4920 - accuracy: 0.8181 - val_loss: 0.5354 - val_accuracy: 0.8158
#
# Epoch 00054: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 55/100
# 800/800 - 20s - loss: 0.4773 - accuracy: 0.8275 - val_loss: 0.5046 - val_accuracy: 0.8292
#
# Epoch 00055: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 56/100
# 800/800 - 20s - loss: 0.4758 - accuracy: 0.8227 - val_loss: 0.5098 - val_accuracy: 0.8108
#
# Epoch 00056: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 57/100
# 800/800 - 19s - loss: 0.4680 - accuracy: 0.8319 - val_loss: 0.5788 - val_accuracy: 0.7925
#
# Epoch 00057: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 58/100
# 800/800 - 19s - loss: 0.4676 - accuracy: 0.8290 - val_loss: 0.4938 - val_accuracy: 0.8292
#
# Epoch 00058: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 59/100
# 800/800 - 19s - loss: 0.4664 - accuracy: 0.8323 - val_loss: 0.4731 - val_accuracy: 0.8358
#
# Epoch 00059: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 60/100
# 800/800 - 19s - loss: 0.4551 - accuracy: 0.8413 - val_loss: 0.4710 - val_accuracy: 0.8283
#
# Epoch 00060: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 61/100
# 800/800 - 19s - loss: 0.4507 - accuracy: 0.8396 - val_loss: 0.5160 - val_accuracy: 0.8325
#
# Epoch 00061: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 62/100
# 800/800 - 19s - loss: 0.4542 - accuracy: 0.8379 - val_loss: 0.4684 - val_accuracy: 0.8417
#
# Epoch 00062: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 63/100
# 800/800 - 19s - loss: 0.4401 - accuracy: 0.8425 - val_loss: 0.4636 - val_accuracy: 0.8408
#
# Epoch 00063: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 64/100
# 800/800 - 20s - loss: 0.4399 - accuracy: 0.8442 - val_loss: 0.4772 - val_accuracy: 0.8300
#
# Epoch 00064: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 65/100
# 800/800 - 20s - loss: 0.4291 - accuracy: 0.8435 - val_loss: 0.4793 - val_accuracy: 0.8358
#
# Epoch 00065: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 66/100
# 800/800 - 20s - loss: 0.4437 - accuracy: 0.8417 - val_loss: 0.4885 - val_accuracy: 0.8408
#
# Epoch 00066: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 67/100
# 800/800 - 19s - loss: 0.4260 - accuracy: 0.8446 - val_loss: 0.4518 - val_accuracy: 0.8417
#
# Epoch 00067: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 68/100
# 800/800 - 20s - loss: 0.4351 - accuracy: 0.8419 - val_loss: 0.5222 - val_accuracy: 0.8258
#
# Epoch 00068: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 69/100
# 800/800 - 19s - loss: 0.4300 - accuracy: 0.8433 - val_loss: 0.5174 - val_accuracy: 0.8183
#
# Epoch 00069: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 70/100
# 800/800 - 20s - loss: 0.4235 - accuracy: 0.8531 - val_loss: 0.4746 - val_accuracy: 0.8292
#
# Epoch 00070: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 71/100
# 800/800 - 20s - loss: 0.4152 - accuracy: 0.8479 - val_loss: 0.4587 - val_accuracy: 0.8308
#
# Epoch 00071: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 72/100
# 800/800 - 19s - loss: 0.4210 - accuracy: 0.8498 - val_loss: 0.4614 - val_accuracy: 0.8450
#
# Epoch 00072: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt
# Epoch 73/100
# 800/800 - 19s - loss: 0.4136 - accuracy: 0.8508 - val_loss: 0.4601 - val_accuracy: 0.8475
#
# Epoch 00073: saving model to /content/drive/MyDrive/Thesis/code/weight/lstm_weight.ckpt

# %% [markdown]
# ##Prediction

# %%
model.load_weights(checkpoint_path)

# %%
# test_path =  "/content/drive/MyDrive/Thesis/m_data/joinTest.csv"
# vf = pd.read_csv(test_path)# converting the data as well as store it into a list
# # valid_data = conversion(vf)
# test_data = vf['seq'].values.ravel()
# test_data = np.asarray(seq_conversion(test_data), dtype=np.float32)
# test_label = vf['variant_label'].to_numpy().astype('int8')
# test_data, test_label = shuffle(test_data, test_label)
# test_data = test_data/4
# test_data = np.expand_dims(test_data, -1)

# %%
predictions = model.predict(test_data,batch_size=1,verbose=0)
rounded_predictions = np.argmax(predictions, axis=-1)
cm = confusion_matrix(y_true = test_label, y_pred= rounded_predictions)

# %%
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cm_plot_labels = ['b117','b1351','p1','b1617.1.2']
print(classification_report(test_label,rounded_predictions))
loss, acc = model.evaluate(test_data, test_label, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       500
#            1       0.94      0.96      0.95       500
#            2       0.98      0.97      0.98       500
#            3       0.97      0.97      0.97       500
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
# 63/63 - 13s - loss: 0.1418 - accuracy: 0.9690
# Restored model, accuracy: 96.90%
# Confusion matrix, without normalization
# [[487   8   1   4]
#  [  8 478   7   7]
#  [  4   8 486   2]
#  [  0  12   1 487]]
